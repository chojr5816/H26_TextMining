# %% [markdown]
# # 네이버 검색 API 예제 코드

# %%
# 네이버 검색 API 예제 - 블로그 검색
import os
import sys
import urllib.request
client_id = "Ai6obFYQTnE3y7qR8ekH"
client_secret = "e3JoIlJ5AN"

encText = urllib.parse.quote("인공지능")

start = 1
display = 10
while start <= 20:
    
    url = "https://openapi.naver.com/v1/search/blog?query=" + encText # JSON 결과
    url += '&start=' + str(start) + '&display=15' # 검색 시작 위치로 start, 최대 15개까지 결과 출력
    # url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과
    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib.request.urlopen(request)
    rescode = response.getcode()
    if(rescode==200):
        response_body = response.read()
        print(response_body.decode('utf-8'))
    else:
        print("Error Code:" + rescode)
        break
    start += display
# Out:
# {
# 	"lastBuildDate":"Thu, 30 Apr 2026 15:26:41 +0900",
# 	"total":3932497,
# 	"start":1,
# 	"display":15,
# 	"items":[
# 		{
# 			"title":"학점은행제 <b>인공지능<\/b> 학위 받고 AI 개발자로 취업했어요.",
# 			"link":"https:\/\/blog.naver.com\/2xhdxhd\/224260183010",
# 			"description":"학점은행제 <b>인공지능<\/b> 학위를 취득하고 꿈에 그리던 IT기업 이직에 성공한 리얼 후기를 들려드리려고 합니다. 최근 제미나이처럼 생성형 AI 기술이 하루가 다르게 변하는 걸 보면서 이제는 <b>인공지능<\/b>을 모르면... ",
# 			"bloggername":"올라! 올리비아-",
# 			"bloggerlink":"blog.naver.com\/2xhdxhd",
# 			"postdate":"20260421"
# 		},
# 		{
# 			"title":"울산AI학원 <b>인공지능<\/b> 활용 수업 후기",
# 			"link":"https:\/\/blog.naver.com\/she_op\/224254871083",
# 			"description":"울산AI학원 <b>인공지능<\/b> 활용 수업 후기 이직을 염두에 두고 있어서 틈날 때마다 공고를 확인했는데요.... 마침 울산AI학원에서 <b>인공지능<\/b>을 활용한 수업을 진행한다고 해서 함께 배우기 괜찮아 보였고, 거기서... ",
# 			"bloggername":"오롯이 여행, 마음먹기 나름 :)",
# 			"bloggerlink":"blog.naver.com\/she_op",
# 			"postdate":"20260416"
# 		},
# 		{
# 			"title":"학점은행제 <b>인공지능<\/b> 비전공자도 학위 취득했어요",
# 			"link":"https:\/\/blog.naver.com\/reebbang\/224267314558",
# 			"description":"IT 기업 취업을 위해 학점은행제 <b>인공지능<\/b> 학사학위를 만든 20대 박O민입니다. 최근 들어 Ai에 대한... 학점은행제 <b>인공지능<\/b> 학사학위를 얻기 위해서는 전공 60점과 교양 30점을 듣고 난 후 총 140점을 채워주셔야... ",
# 			"bloggername":"30's Mood",
# 			"bloggerlink":"blog.naver.com\/reebbang",
# 			"postdate":"20260428"
# 		},
# 		{
# 			"title":"컴퓨터학원 실용적인 <b>인공지능<\/b> 수업과정",
# 			"link":"https:\/\/blog.naver.com\/foryou1035\/224160610941",
# 			"description":"요즘 <b>인공지능<\/b>이 화두인데요. 처음에는 똑똑한 기능에 신기함이 컸지만, 시간이 갈수록 미묘한 감정이... 현재는 직장에서 <b>인공지능<\/b> 교육을 담당하게 되었고, 퇴근 후에는 취미로 웹사이트를 만들고 있어요.... ",
# 			"bloggername":"Ssong Story ♡",
# 			"bloggerlink":"blog.naver.com\/foryou1035",
# 			"postdate":"20260126"
# 		},
# 		{
# 			"title":"<b>인공지능<\/b> 자격증 취득과정 및 취업 정보 정리",
# 			"link":"https:\/\/blog.naver.com\/gustlr00\/224087574160",
# 			"description":"<b>인공지능<\/b> 자격증 취득과정 및 취업 정보 정리 “AI를 이해하는 사람과 그렇지 못한 사람의 차이가 점점 더 커지고 있다&quot;라는 말을 실감하게 되는 요즘, 직장 내에서도, 취업 시장에서도 <b>인공지능<\/b> 기술을 다룰... ",
# 			"bloggername":"〃다시 만나는 그날 까지 〃",
# 			"bloggerlink":"blog.naver.com\/gustlr00",
# 			"postdate":"20251125"
# 		},
# 		{
# 			"title":"학점은행제 <b>인공지능<\/b> 학위로 AI회사에 이직 성공했어요.",
# 			"link":"https:\/\/blog.naver.com\/seo8810603\/224226152116",
# 			"description":"저는 학점은행제 <b>인공지능<\/b> 학위로 이직까지 성공하게 된 30대 박ㅇ우입니다. 요즘 워낙 AI 기술이 많이... 솔직히 저도 처음에는 <b>인공지능<\/b>의 발전을 그렇게 달갑게 생각하진 않았어요. 사람의 일자리를... ",
# 			"bloggername":"Seo's reptile and Water life story",
# 			"bloggerlink":"blog.naver.com\/seo8810603",
# 			"postdate":"20260323"
# 		},
# 		{
# 			"title":"<b>인공지능<\/b> AI 소프트웨어 MAS등록, 조달청 신규공고",
# 			"link":"https:\/\/blog.naver.com\/wisdom_hjs\/224252952517",
# 			"description":"공고번호 R26BK01450117-000 「<b>인공지능<\/b>(AI)소프트웨어 다수공급자계약(MAS)」신규공고입니다. 2026년 4월에... 공고서에 명시적으로 &quot;세부품명이 <b>인공지능<\/b>(AI)소프트웨어인 경우는 시중거래실적 제출을 생략할 수... ",
# 			"bloggername":"지혜로운 행정사",
# 			"bloggerlink":"blog.naver.com\/wisdom_hjs",
# 			"postdate":"20260415"
# 		},
# 		{
# 			"title":"영상편집 직업훈련 추천 : <b>인공지능<\/b> 기반의 교육",
# 			"link":"https:\/\/blog.naver.com\/urmyver\/224267848909",
# 			"description":"영상편집 직업훈련 추천 <b>인공지능<\/b> 기반의 교육 스마트폰이 출시되기 이전에도 Youtube와 판도라 TV처럼... 하지만, 현재에는 <b>인공지능<\/b> 기술을 활용하여 자동으로 컷을 편집하거나 자막을 생성하고, 음성 보정 등... ",
# 			"bloggername":"주들의 그리 대단하진 않지만 굉장한 이야기",
# 			"bloggerlink":"blog.naver.com\/urmyver",
# 			"postdate":"20260428"
# 		},
# 		{
# 			"title":"나는 AI로 급등주에 투자한다 \/ 곽경일 \/ <b>인공지능<\/b> 퀀트 투자... ",
# 			"link":"https:\/\/blog.naver.com\/astel_erste\/224257624806",
# 			"description":"나는 AI로 급등주에 투자한다 곽경일 경제\/경영 알에이치코리아 p.360 2026.03.30 파이썬을 통한 <b>인공지능<\/b>... 곽경일 작가 소개 목차 책 속으로 &amp; 나의 생각 곽경일의 『나는 AI로 급등주에 투자한다』는 <b>인공지능<\/b>과... ",
# 			"bloggername":"텍스트로 세상을 드로잉 하고픈 야담",
# 			"bloggerlink":"blog.naver.com\/astel_erste",
# 			"postdate":"20260419"
# 		},
# 		{
# 			"title":"<b>인공지능<\/b>(AI) 시대, 앞으로 일자리는 어떻게 변할까요?",
# 			"link":"https:\/\/blog.naver.com\/molab_suda\/224242653040",
# 			"description":"- ｢APEC 미래 일자리 포럼: <b>인공지능<\/b>(AI)와 인구구조 변화｣ 개최 - 산업전환 고용안정 기본계획... 이덕만 포스코 지능화센터장은 기존 수작업으로 진행하던 용광로 작업을, 데이터를 학습해 스스로 규칙을... ",
# 			"bloggername":"고용노동부 공식 블로그",
# 			"bloggerlink":"blog.naver.com\/molab_suda",
# 			"postdate":"20260406"
# 		},
# 		{
# 			"title":"<b>인공지능<\/b> 교육 AI교육 키트 언플러그드 코딩 주미AI",
# 			"link":"https:\/\/blog.naver.com\/alley1980\/224229641240",
# 			"description":"<b>인공지능<\/b> 교육 AI교육 키트 언플러그드 코딩 주미AI 어느덧 따스한 바람이 부는 새학기 시즌이라 아이들 교육 문제로 고민이 많은 시기지요. 요즘은 학교 수업에서도 <b>인공지능<\/b> 교육 비중이 커지다 보니 집에서도... ",
# 			"bloggername":"고고씨네 소소한 일상",
# 			"bloggerlink":"blog.naver.com\/alley1980",
# 			"postdate":"20260325"
# 		},
# 		{
# 			"title":"개인용 슈퍼컴퓨터로 AI <b>인공지능<\/b> 연구 효율... ",
# 			"link":"https:\/\/blog.naver.com\/gudrkq89\/224265949681",
# 			"description":"<b>인공지능<\/b> 모델 학습이나 복잡한 데이터 분석을 연구하면서 클라우드 비용 부담이나 느린 처리 속도... #NVIDIADGXSpark #엔비디아스파크 #개인용슈퍼컴퓨터 #AI워크스테이션 #그레이스블랙웰 #<b>인공지능<\/b>연구... ",
# 			"bloggername":"최형갭v 부동산, 임장, N잡, 상품리뷰, 블로그",
# 			"bloggerlink":"blog.naver.com\/gudrkq89",
# 			"postdate":"20260426"
# 		},
# 		{
# 			"title":"능력보다 중요한 것? AI(<b>인공지능<\/b>)시대 더 중요해진 경험의 힘",
# 			"link":"https:\/\/blog.naver.com\/cog_nition\/224242675913",
# 			"description":"이러한 변화에 따라 정부도 <b>인공지능<\/b>에 맞는 디지털 미래인재를 양성하겠다며 <b>인공지능<\/b>을 어떻게 잘 활용할 것인가에 대해 정책을 내놓고 있습니다. 불과 최근까지만 해도 프롬프트를 잘 던지면, 다시 말해... ",
# 			"bloggername":"일희일희 육아",
# 			"bloggerlink":"blog.naver.com\/cog_nition",
# 			"postdate":"20260420"
# 		},
# 		{
# 			"title":"AI학과 대학 <b>인공지능<\/b>을 다루려면",
# 			"link":"https:\/\/blog.naver.com\/no1kwangwoon\/224253183722",
# 			"description":"자율주행부터 맞춤형 서비스까지 모든 산업군이 <b>인공지능<\/b>을 중심으로 재편되면서, 관련 지식을 갖춘... 본교, 광운대학교 정보과학교육원의 <b>인공지능<\/b> 전공은 이러한 입시의 한계를 극복하기 위해 성적 반영... ",
# 			"bloggername":"광운대학교 정보과학교육원 공식블로그",
# 			"bloggerlink":"blog.naver.com\/no1kwangwoon",
# 			"postdate":"20260415"
# 		},
# 		{
# 			"title":"미국 매체들의 <b>인공지능<\/b>(AI) 군사작전 적용 우려  [제1893호]",
# 			"link":"https:\/\/blog.naver.com\/kima20298\/224255744328",
# 			"description":"Fury)’에 <b>인공지능<\/b>(AI)을 처음으로 적용하였다고 발표하였다. 3월 11일 미국 The War Zone은 해당... 나타났다며 <b>인공지능<\/b>의 군사작전 적용에 따른 부정적 측면을 지적하였다. 또한 3월 18일 War on the Rocks... ",
# 			"bloggername":"한국군사문제연구원",
# 			"bloggerlink":"blog.naver.com\/kima20298",
# 			"postdate":"20260417"
# 		}
# 	]
# }
# {
# 	"lastBuildDate":"Thu, 30 Apr 2026 15:26:41 +0900",
# 	"total":3932502,
# 	"start":11,
# 	"display":15,
# 	"items":[
# 		{
# 			"title":"<b>인공지능<\/b> 교육 AI교육 키트 언플러그드 코딩 주미AI",
# 			"link":"https:\/\/blog.naver.com\/alley1980\/224229641240",
# 			"description":"<b>인공지능<\/b> 교육 AI교육 키트 언플러그드 코딩 주미AI 어느덧 따스한 바람이 부는 새학기 시즌이라 아이들 교육 문제로 고민이 많은 시기지요. 요즘은 학교 수업에서도 <b>인공지능<\/b> 교육 비중이 커지다 보니 집에서도... ",
# 			"bloggername":"고고씨네 소소한 일상",
# 			"bloggerlink":"blog.naver.com\/alley1980",
# 			"postdate":"20260325"
# 		},
# 		{
# 			"title":"개인용 슈퍼컴퓨터로 AI <b>인공지능<\/b> 연구 효율... ",
# 			"link":"https:\/\/blog.naver.com\/gudrkq89\/224265949681",
# 			"description":"<b>인공지능<\/b> 모델 학습이나 복잡한 데이터 분석을 연구하면서 클라우드 비용 부담이나 느린 처리 속도... #NVIDIADGXSpark #엔비디아스파크 #개인용슈퍼컴퓨터 #AI워크스테이션 #그레이스블랙웰 #<b>인공지능<\/b>연구... ",
# 			"bloggername":"최형갭v 부동산, 임장, N잡, 상품리뷰, 블로그",
# 			"bloggerlink":"blog.naver.com\/gudrkq89",
# 			"postdate":"20260426"
# 		},
# 		{
# 			"title":"능력보다 중요한 것? AI(<b>인공지능<\/b>)시대 더 중요해진 경험의 힘",
# 			"link":"https:\/\/blog.naver.com\/cog_nition\/224242675913",
# 			"description":"이러한 변화에 따라 정부도 <b>인공지능<\/b>에 맞는 디지털 미래인재를 양성하겠다며 <b>인공지능<\/b>을 어떻게 잘 활용할 것인가에 대해 정책을 내놓고 있습니다. 불과 최근까지만 해도 프롬프트를 잘 던지면, 다시 말해... ",
# 			"bloggername":"일희일희 육아",
# 			"bloggerlink":"blog.naver.com\/cog_nition",
# 			"postdate":"20260420"
# 		},
# 		{
# 			"title":"AI학과 대학 <b>인공지능<\/b>을 다루려면",
# 			"link":"https:\/\/blog.naver.com\/no1kwangwoon\/224253183722",
# 			"description":"자율주행부터 맞춤형 서비스까지 모든 산업군이 <b>인공지능<\/b>을 중심으로 재편되면서, 관련 지식을 갖춘... 본교, 광운대학교 정보과학교육원의 <b>인공지능<\/b> 전공은 이러한 입시의 한계를 극복하기 위해 성적 반영... ",
# 			"bloggername":"광운대학교 정보과학교육원 공식블로그",
# 			"bloggerlink":"blog.naver.com\/no1kwangwoon",
# 			"postdate":"20260415"
# 		},
# 		{
# 			"title":"미국 매체들의 <b>인공지능<\/b>(AI) 군사작전 적용 우려  [제1893호]",
# 			"link":"https:\/\/blog.naver.com\/kima20298\/224255744328",
# 			"description":"Fury)’에 <b>인공지능<\/b>(AI)을 처음으로 적용하였다고 발표하였다. 3월 11일 미국 The War Zone은 해당... 나타났다며 <b>인공지능<\/b>의 군사작전 적용에 따른 부정적 측면을 지적하였다. 또한 3월 18일 War on the Rocks... ",
# 			"bloggername":"한국군사문제연구원",
# 			"bloggerlink":"blog.naver.com\/kima20298",
# 			"postdate":"20260417"
# 		},
# 		{
# 			"title":"Photoshop 포토샵 <b>인공지능<\/b> 기능 인물 사람 생성형 지우기",
# 			"link":"https:\/\/blog.naver.com\/korovo\/224249852435",
# 			"description":"최근 1-2년 사이에 포토샵에 다양한 <b>인공지능<\/b> 기능이 추가되었는데 불필요한 개체나 인물, 사람을 지우는 것이 가능한 생성형 지우기 기능을 소개해 보겠다. ✅Adobe Photohsop 바로 가기 <b>인공지능<\/b> 기능... ",
# 			"bloggername":"잡동사니 저장소",
# 			"bloggerlink":"blog.naver.com\/korovo",
# 			"postdate":"20260415"
# 		},
# 		{
# 			"title":"서울소셜리딩그룹 토요포럼 646회 - <b>인공지능<\/b> 알트 AI와... ",
# 			"link":"https:\/\/blog.naver.com\/kyoung37\/224265156911",
# 			"description":"오전 9시 30분부터 12시까지 서울소셜리딩그룹 토요포럼 646회 - 전종현 교수님 <b>인공지능<\/b> 알트 AI와... <b>인공지능<\/b> 알트 ALT AI 2. 구글 Vids AI로 신박한 동영상 만들기 ☞ 강사: 전종현 교수님, 김미경 강사... ",
# 			"bloggername":"김미경 AI 스마트폰교육010-9909-1533",
# 			"bloggerlink":"blog.naver.com\/kyoung37",
# 			"postdate":"20260425"
# 		},
# 		{
# 			"title":"학점은행제 <b>인공지능<\/b>, 학위 따고 재취업 성공(비전공자)",
# 			"link":"https:\/\/blog.naver.com\/jje423\/224228420448",
# 			"description":"학점은행제 <b>인공지능<\/b>, 학위 따고 재취업 성공(비전공자) 안녕하세요! 4년제 대학을 졸업하고도 전공... 그러다 우리 일상 곳곳에 스며든 <b>인공지능<\/b>(AI) 분야를 보며 &quot;지금이라도 이 길을 준비하면 늦지 않을까?... ",
# 			"bloggername":"욕심많은 별들맘 이야기",
# 			"bloggerlink":"blog.naver.com\/jje423",
# 			"postdate":"20260325"
# 		},
# 		{
# 			"title":"<b>인공지능<\/b> 관련성 혼재로 인한 자기 모순과 오류",
# 			"link":"https:\/\/blog.naver.com\/darksana\/224266618721",
# 			"description":"이래서 논쟁이 되는 건데 인간이 하면 이해라도 하겠는데 <b>인공지능<\/b>이 하니까 내 시간 잡아먹는... <b>인공지능<\/b>이 참 위험해 보이는 게 저놈이 인간처럼 가치판단을 하려고 한다니까? 결론까지 미리 정해놓고 그걸... ",
# 			"bloggername":"éphémère",
# 			"bloggerlink":"blog.naver.com\/darksana",
# 			"postdate":"20260427"
# 		},
# 		{
# 			"title":"한국공학대학교 TU AI 캠퍼스 : <b>인공지능<\/b> 캠퍼스의 출현! 두둥탁-",
# 			"link":"https:\/\/blog.naver.com\/tukorea_official\/224268777670",
# 			"description":"TU AI 캠퍼스 : <b>인공지능<\/b> 캠퍼스의 출연? 챗GPT, 제미나이, 클로드, 퍼플렉시티까지. 불과 몇 년 전만... 하지만 TU AI Campus가 자리 잡게 되면 말그대로 <b>인공지능<\/b> 캠퍼스 시스템으로 학생들은 자신의 학습 이력과... ",
# 			"bloggername":"한국공학대학교 공식블로그",
# 			"bloggerlink":"blog.naver.com\/tukorea_official",
# 			"postdate":"20260429"
# 		},
# 		{
# 			"title":"<b>인공지능<\/b>을 위한 자동화 공정, MLOps파이프라인",
# 			"link":"https:\/\/blog.naver.com\/himediacokr\/224263978442",
# 			"description":"<b>인공지능<\/b>이 날마다 발전하고 있는 요즘, 단순히 똑똑한 AI를 만드는 것보다 시간이 지나도 변함없이... AI의 유통기한을 책임지는 시스템, MLOps의 정의 우리는 흔히 <b>인공지능<\/b>을 한 번 개발해두면 영원히... ",
# 			"bloggername":"하이미디어 아카데미 공식블로그",
# 			"bloggerlink":"blog.naver.com\/himediacokr",
# 			"postdate":"20260424"
# 		},
# 		{
# 			"title":"학점은행제 <b>인공지능<\/b> 온라인으로 학위 취득했어요",
# 			"link":"https:\/\/blog.naver.com\/reebbang\/224181846192",
# 			"description":"저는 비전공자로 직장 생활을 하다가 미래를 위해 학점은행제 <b>인공지능<\/b> 전공을 통해 학사학위를 취득했던 20대 남성입니다. 처음에는 솔직히 <b>인공지능<\/b>이라는 단어가 너무 막연하게 느껴졌습니다. &quot;AI가... ",
# 			"bloggername":"30's Mood",
# 			"bloggerlink":"blog.naver.com\/reebbang",
# 			"postdate":"20260213"
# 		},
# 		{
# 			"title":"일하는 방식이 바뀌는 <b>인공지능<\/b>(AI) 시대 ‘직업공통능력’... ",
# 			"link":"https:\/\/blog.naver.com\/molab_suda\/224268212295",
# 			"description":"<b>인공지능<\/b>(AI)활용능력, 디지털책임의식, 산업안전보건의식 등 포함한 7개 영역으로 개편 생성형 AI가... 노동시장 변화에 따라 활용도가 낮아진 항목은 과감히 폐지하고, <b>인공지능<\/b>(AI) 활용능력... ",
# 			"bloggername":"고용노동부 공식 블로그",
# 			"bloggerlink":"blog.naver.com\/molab_suda",
# 			"postdate":"20260428"
# 		},
# 		{
# 			"title":"수성영상미디어센터 대구 AI 교육 <b>인공지능<\/b> 강좌 무료 유료 정보",
# 			"link":"https:\/\/blog.naver.com\/suseongblog\/224254525958",
# 			"description":"수성영상미디어센터 대구 AI 교육 <b>인공지능<\/b> 강좌 무료 유료 정보 바야흐로 AI 시대 다들 느끼고... 대구 시민들의 든든한 등대 역할을 해주는 수성영상미디어센터에서 AI 교육 <b>인공지능<\/b> 강좌를 무료, 유료로... ",
# 			"bloggername":"수성구청 블로그",
# 			"bloggerlink":"blog.naver.com\/suseongblog",
# 			"postdate":"20260416"
# 		},
# 		{
# 			"title":"몰트북 충격 읽어보니 AI 시대 얼마나 바뀔까 <b>인공지능<\/b> 책 추천",
# 			"link":"https:\/\/blog.naver.com\/limhyunae\/224248225786",
# 			"description":"몰트북 충격 읽어보니 AI 시대 얼마나 바뀔까 <b>인공지능<\/b> 책 추천 요즘 뉴스나 유튜브를 보다 보면 AI, <b>인공지능<\/b> 이야기가 빠지지 않고 등장하는 것 같아요. 단순히 기술 발전 정도가 아니라 우리삶 자체가... ",
# 			"bloggername":"달달한 그녀의 일상",
# 			"bloggerlink":"blog.naver.com\/limhyunae",
# 			"postdate":"20260410"
# 		}
# 	]
# }

# %%
# 네이버 검색 API 예제 - 블로그 검색
import os
import sys
import urllib.request
client_id = "Ai6obFYQTnE3y7qR8ekH"
client_secret = "e3JoIlJ5AN"

encText = urllib.parse.quote("인공지능")

start = 1
display = 10
url = "https://openapi.naver.com/v1/search/news?query=" + encText # JSON 결과
url += '&start=' + str(start) + '&display=15' # 검색 시작 위치로 start, 최대 15개까지 결과 출력
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    news_data = response_body.decode('utf-8')
    print(news_data)
else:
    print("Error Code:" + rescode)
# Out:
# {
# 	"lastBuildDate":"Thu, 30 Apr 2026 15:39:24 +0900",
# 	"total":3911837,
# 	"start":1,
# 	"display":15,
# 	"items":[
# 		{
# 			"title":"[금융가 브리프] KB국민은행 신한은행 하나은행 우리은행 NH농협은행 IB...",
# 			"originallink":"https:\/\/www.s-journal.co.kr\/news\/articleView.html?idxno=41002",
# 			"link":"https:\/\/www.s-journal.co.kr\/news\/articleView.html?idxno=41002",
# 			"description":"■ NH농협은행, 에이전틱 AI 프로그램 실시 <b>인공지능<\/b>이 단순한 기술을 넘어 실무 해결사로 거듭나는 가운데, NH농협은행이 <b>인공지능<\/b> 에이전트 개발을 통한 디지털 혁신에 속도를 낸다. NH농협은행은 29일부터 이틀간 개발... ",
# 			"pubDate":"Thu, 30 Apr 2026 15:38:00 +0900"
# 		},
# 		{
# 			"title":"네이버 엔터프라이즈 부문, GPU·협업툴로 매출 18.8%↑…공공·글로벌 ...",
# 			"originallink":"https:\/\/zdnet.co.kr\/view\/?no=20260430143332",
# 			"link":"https:\/\/n.news.naver.com\/mnews\/article\/092\/0002420984?sid=105",
# 			"description":"네이버가 <b>인공지능<\/b>(AI) 기반 B2B 사업 확대를 중심으로 엔터프라이즈 부문 성장세를 이어가고 있다. 인프라와 협업툴 등 핵심 사업이 고르게 성장하며 글로벌 소버린 AI 시장 공략과 공공·해외 확장 전략에 박차를... ",
# 			"pubDate":"Thu, 30 Apr 2026 15:38:00 +0900"
# 		},
# 		{
# 			"title":"삼성전기, 분기 매출 3조원 돌파... “산업·전장용 고부가제품 견조한...",
# 			"originallink":"https:\/\/www.chosun.com\/economy\/tech_it\/2026\/04\/30\/NV4SLRQP2JASBEEAGKD7APKVHM\/?utm_source=naver&utm_medium=referral&utm_campaign=naver-news",
# 			"link":"https:\/\/n.news.naver.com\/mnews\/article\/023\/0003973995?sid=105",
# 			"description":"산업·전장용 고부가가치 제품의 견조한 수요를 바탕으로 AI(<b>인공지능<\/b>) 서버 및 첨단 운전자 지원 시스템(ADAS)용 적층 세라믹 커패시터(MLCC), 플립칩 볼 그리드 어레이(FC-BGA) 등의 공급을 확대해 실적이 개선됐다.... ",
# 			"pubDate":"Thu, 30 Apr 2026 15:38:00 +0900"
# 		},
# 		{
# 			"title":"삼성SDS, 행정안전부 ‘온AI’ 공식 협업 솔루션 선정",
# 			"originallink":"https:\/\/www.chosun.com\/economy\/tech_it\/2026\/04\/30\/YUAHNR64GRFMZOQAWH2MLYRVQY\/?utm_source=naver&utm_medium=referral&utm_campaign=naver-news",
# 			"link":"https:\/\/n.news.naver.com\/mnews\/article\/023\/0003973996?sid=105",
# 			"description":"삼성SDS는 생성형 AI(<b>인공지능<\/b>) 기반 협업 솔루션 ‘브리티웍스’가 행정안전부 ‘온AI’의 공식 협업 솔루션으로 선정됐다고 30일 밝혔다. 온AI는 정부의 지능형 업무 관리 플랫폼이다. 삼성SDS는 행정안전부가 주관하는... ",
# 			"pubDate":"Thu, 30 Apr 2026 15:38:00 +0900"
# 		},
# 		{
# 			"title":"나델라 CEO &quot;'에이전틱 컴퓨팅 시대 왔다…전력 1GW 추가 확보&quot;",
# 			"originallink":"https:\/\/zdnet.co.kr\/view\/?no=20260430143700",
# 			"link":"https:\/\/n.news.naver.com\/mnews\/article\/092\/0002420982?sid=105",
# 			"description":"마이크로소프트가 <b>인공지능<\/b>(AI) 인프라 구축 확대를 위해 추가 전력 용량을 확보했다. 사티아 나델라 마이크로소프트 최고경영자(CEO)는 29일(현지시간) 2026 회계연도 3분기 실적 발표를 공유하며 링크드인을 통해... ",
# 			"pubDate":"Thu, 30 Apr 2026 15:38:00 +0900"
# 		},
# 		{
# 			"title":"삼성SDS, '브리티웍스'로 정부 온AI 모바일 서비스 지원",
# 			"originallink":"https:\/\/www.ziksir.com\/news\/articleView.html?idxno=132632",
# 			"link":"https:\/\/www.ziksir.com\/news\/articleView.html?idxno=132632",
# 			"description":"[삼성SDS]  삼성SDS의 생성형 <b>인공지능<\/b>(AI) 기반 협업솔루션 '브리티웍스'가 행정안전부 '온AI(지능형 업무관리 플랫폼)'의 공식 협업 솔루션으로 선정됐다고 30일 밝혔다. 삼성SDS는 행정안전부와 과학기술정보통신부가... ",
# 			"pubDate":"Thu, 30 Apr 2026 15:38:00 +0900"
# 		},
# 		{
# 			"title":"삼성바이오로직스, 릴리와 손잡고 K-바이오텍 최대 30곳 육성…&quot;내년부...",
# 			"originallink":"https:\/\/www.asiatoday.co.kr\/kn\/view.php?key=20260430010009869",
# 			"link":"https:\/\/www.asiatoday.co.kr\/kn\/view.php?key=20260430010009869",
# 			"description":"항체뿐 아니라 세포·유전자치료제(CGT), 펩타이드, <b>인공지능<\/b>(AI) 신약 등 다양한 분야를 포괄한다.입주 기간은 기본 2년에 추가 2년 연장이 가능하며, 구체적인 모집은 올해 4분기부터 진행될 예정이다.... ",
# 			"pubDate":"Thu, 30 Apr 2026 15:38:00 +0900"
# 		},
# 		{
# 			"title":"제주4·3 기억, AI 콘텐츠로 확장한다… 콘텐츠진흥원·4·3평화재단 맞...",
# 			"originallink":"http:\/\/www.fnnews.com\/news\/202604301535316268",
# 			"link":"https:\/\/n.news.naver.com\/mnews\/article\/014\/0005515905?sid=102",
# 			"description":"제주4·3의 기억과 제주 고유의 역사·문화 자산을 <b>인공지능<\/b>(AI) 기반 콘텐츠로 확장하는 협력 사업이 추진된다. 지역의 아픈 역사와 문화적 정체성을 미래형 영상 콘텐츠로 재해석해 국내외로 알리고 청년 창작자와... ",
# 			"pubDate":"Thu, 30 Apr 2026 15:38:00 +0900"
# 		},
# 		{
# 			"title":"KB금융, 초고령화사회 대응 위해 시니어 케어 확장... '피지컬 AI 돌봄 서...",
# 			"originallink":"http:\/\/www.thefirstmedia.net\/news\/articleView.html?idxno=198932",
# 			"link":"http:\/\/www.thefirstmedia.net\/news\/articleView.html?idxno=198932",
# 			"description":"30일 KB금융은 오는 5월 6일부터 8일까지 서울 코엑스에서 열리는 AI EXPO KOREA 2026(국제<b>인공지능<\/b>대전, 이하 AI엑스포)에서 국내 금융권 최초로 휴머노이드 로봇을 활용한 시니어 케어 특화 '피지컬 AI (Physical AI) 돌봄... ",
# 			"pubDate":"Thu, 30 Apr 2026 15:38:00 +0900"
# 		},
# 		{
# 			"title":"오세훈 2호 공약은 ‘마음 건강’…“누구도 외롭게 두지 않을 것”",
# 			"originallink":"https:\/\/biz.chosun.com\/policy\/politics\/election\/2026\/04\/30\/KULOU3YK6ZHLBCSX464QVIUE7Y\/?utm_source=naver&utm_medium=original&utm_campaign=biz",
# 			"link":"https:\/\/n.news.naver.com\/mnews\/article\/366\/0001161160?sid=162",
# 			"description":"실직이나 이혼 등 행정 데이터를 활용해 위기 가구를 선제적으로 발굴하고, AI(<b>인공지능<\/b>)와 카카오톡을 결합한 ‘상시 안부 확인 시스템’을 구축한다. 영국의 ‘맨즈 쉐드(Men’s Shed)’를 벤치마킹해 목공 등 생산적... ",
# 			"pubDate":"Thu, 30 Apr 2026 15:38:00 +0900"
# 		},
# 		{
# 			"title":"행안부 AI 안전신문고 1단계 개발 완료",
# 			"originallink":"http:\/\/www.ttlnews.com\/news\/articleView.html?idxno=3103961",
# 			"link":"http:\/\/www.ttlnews.com\/news\/articleView.html?idxno=3103961",
# 			"description":"우리 국민이 일상에서 마주하는 위험 요소를 사진 한 장으로 포착하고, 이를 <b>인공지능<\/b>(AI)이 스스로 분석해 소관 부서로 즉시 넘기는 지능형 안전 행정 시대가 열린다. LG AI연구원과 한국전자기술연구원(KETI)이... ",
# 			"pubDate":"Thu, 30 Apr 2026 15:38:00 +0900"
# 		},
# 		{
# 			"title":"메모리 정확도 100배·처리속도 7.6배 개선할 최적 구조 찾았다",
# 			"originallink":"https:\/\/zdnet.co.kr\/view\/?no=20260430151933",
# 			"link":"https:\/\/n.news.naver.com\/mnews\/article\/092\/0002420983?sid=105",
# 			"description":"<b>인공지능<\/b>(AI) 성능을 좌우하는 메모리 반도체 정확도를 100배, 처리 속도는 7.6배 정도를 개선할 수 있는 기술이 개발됐다. 고려대학교는 유현용 전기전자공학부 교수와 DGIST 권혁준 교수 연구팀이 p-채널 실리콘과... ",
# 			"pubDate":"Thu, 30 Apr 2026 15:38:00 +0900"
# 		},
# 		{
# 			"title":"해양환경공단, AI·데이터 활용 창업생태계 활성화 박차",
# 			"originallink":"https:\/\/www.s-journal.co.kr\/news\/articleView.html?idxno=41004",
# 			"link":"https:\/\/www.s-journal.co.kr\/news\/articleView.html?idxno=41004",
# 			"description":"해양환경공단이 제주에서 <b>인공지능<\/b>(AI)·데이터 활용 확산과 창업생태계 활성화를 위한 공동 워크숍을 개최했다. 해양환경공단은 지난 22일부터 24일까지 3일간 제주 서귀포시 한국지능정보사회진흥원(이하 NIA)... ",
# 			"pubDate":"Thu, 30 Apr 2026 15:38:00 +0900"
# 		},
# 		{
# 			"title":"삼성전자, 1분기 영업익 57.2조-반도체로만 53.7조 벌었다",
# 			"originallink":"http:\/\/www.techholic.co.kr\/news\/articleView.html?idxno=221017",
# 			"link":"http:\/\/www.techholic.co.kr\/news\/articleView.html?idxno=221017",
# 			"description":"특히 영업이익은 국내 기업 가운데 역대 최고를 넘어 글로벌 기업 가운데서도 최고의 수준을 기록, <b>인공지능<\/b>(AI) 확산에 따른 메모리 수요 증가세로인한 반도체 슈퍼사이클의 최대 수혜자임을 증명했다. 삼성전자는... ",
# 			"pubDate":"Thu, 30 Apr 2026 15:38:00 +0900"
# 		},
# 		{
# 			"title":"광주광역시, 자동차·<b>인공지능<\/b>·에너지 유망 기업 11개사와 1605억원 투자...",
# 			"originallink":"http:\/\/www.fnnews.com\/news\/202604301519258427",
# 			"link":"https:\/\/n.news.naver.com\/mnews\/article\/014\/0005515902?sid=102",
# 			"description":"광주광역시가 30일 자동차·<b>인공지능<\/b>(AI)·에너지 분야 유망 기업 11개사와 총 1605억원 규모의 투자 유치 협약을 체결했다. 11개 기업은 ㈜디엔, ㈜나전, ㈜리얼디자인테크, 하이퍼협동조합, ㈜달구, ㈜모리스, ㈜에스더블유엠... ",
# 			"pubDate":"Thu, 30 Apr 2026 15:37:00 +0900"
# 		}
# 	]
# }

# %%
import json

py_news_data = json.loads(news_data)
type(py_news_data)
# Out:
# dict

# %%
news_corpus = []
news_corpus += py_news_data['items']
news_corpus
# Out:
# [{'title': '[금융가 브리프] KB국민은행 신한은행 하나은행 우리은행 NH농협은행 IB...',
#   'originallink': 'https://www.s-journal.co.kr/news/articleView.html?idxno=41002',
#   'link': 'https://www.s-journal.co.kr/news/articleView.html?idxno=41002',
#   'description': '■ NH농협은행, 에이전틱 AI 프로그램 실시 <b>인공지능</b>이 단순한 기술을 넘어 실무 해결사로 거듭나는 가운데, NH농협은행이 <b>인공지능</b> 에이전트 개발을 통한 디지털 혁신에 속도를 낸다. NH농협은행은 29일부터 이틀간 개발... ',
#   'pubDate': 'Thu, 30 Apr 2026 15:38:00 +0900'},
#  {'title': '네이버 엔터프라이즈 부문, GPU·협업툴로 매출 18.8%↑…공공·글로벌 ...',
#   'originallink': 'https://zdnet.co.kr/view/?no=20260430143332',
#   'link': 'https://n.news.naver.com/mnews/article/092/0002420984?sid=105',
#   'description': '네이버가 <b>인공지능</b>(AI) 기반 B2B 사업 확대를 중심으로 엔터프라이즈 부문 성장세를 이어가고 있다. 인프라와 협업툴 등 핵심 사업이 고르게 성장하며 글로벌 소버린 AI 시장 공략과 공공·해외 확장 전략에 박차를... ',
#   'pubDate': 'Thu, 30 Apr 2026 15:38:00 +0900'},
#  {'title': '삼성전기, 분기 매출 3조원 돌파... “산업·전장용 고부가제품 견조한...',
#   'originallink': 'https://www.chosun.com/economy/tech_it/2026/04/30/NV4SLRQP2JASBEEAGKD7APKVHM/?utm_source=naver&utm_medium=referral&utm_campaign=naver-news',
#   'link': 'https://n.news.naver.com/mnews/article/023/0003973995?sid=105',
#   'description': '산업·전장용 고부가가치 제품의 견조한 수요를 바탕으로 AI(<b>인공지능</b>) 서버 및 첨단 운전자 지원 시스템(ADAS)용 적층 세라믹 커패시터(MLCC), 플립칩 볼 그리드 어레이(FC-BGA) 등의 공급을 확대해 실적이 개선됐다.... ',
#   'pubDate': 'Thu, 30 Apr 2026 15:38:00 +0900'},
#  {'title': '삼성SDS, 행정안전부 ‘온AI’ 공식 협업 솔루션 선정',
#   'originallink': 'https://www.chosun.com/economy/tech_it/2026/04/30/YUAHNR64GRFMZOQAWH2MLYRVQY/?utm_source=naver&utm_medium=referral&utm_campaign=naver-news',
#   'link': 'https://n.news.naver.com/mnews/article/023/0003973996?sid=105',
#   'description': '삼성SDS는 생성형 AI(<b>인공지능</b>) 기반 협업 솔루션 ‘브리티웍스’가 행정안전부 ‘온AI’의 공식 협업 솔루션으로 선정됐다고 30일 밝혔다. 온AI는 정부의 지능형 업무 관리 플랫폼이다. 삼성SDS는 행정안전부가 주관하는... ',
#   'pubDate': 'Thu, 30 Apr 2026 15:38:00 +0900'},
#  {'title': "나델라 CEO &quot;'에이전틱 컴퓨팅 시대 왔다…전력 1GW 추가 확보&quot;",
#   'originallink': 'https://zdnet.co.kr/view/?no=20260430143700',
#   'link': 'https://n.news.naver.com/mnews/article/092/0002420982?sid=105',
#   'description': '마이크로소프트가 <b>인공지능</b>(AI) 인프라 구축 확대를 위해 추가 전력 용량을 확보했다. 사티아 나델라 마이크로소프트 최고경영자(CEO)는 29일(현지시간) 2026 회계연도 3분기 실적 발표를 공유하며 링크드인을 통해... ',
#   'pubDate': 'Thu, 30 Apr 2026 15:38:00 +0900'},
#  {'title': "삼성SDS, '브리티웍스'로 정부 온AI 모바일 서비스 지원",
#   'originallink': 'https://www.ziksir.com/news/articleView.html?idxno=132632',
#   'link': 'https://www.ziksir.com/news/articleView.html?idxno=132632',
#   'description': "[삼성SDS]  삼성SDS의 생성형 <b>인공지능</b>(AI) 기반 협업솔루션 '브리티웍스'가 행정안전부 '온AI(지능형 업무관리 플랫폼)'의 공식 협업 솔루션으로 선정됐다고 30일 밝혔다. 삼성SDS는 행정안전부와 과학기술정보통신부가... ",
#   'pubDate': 'Thu, 30 Apr 2026 15:38:00 +0900'},
#  {'title': '삼성바이오로직스, 릴리와 손잡고 K-바이오텍 최대 30곳 육성…&quot;내년부...',
#   'originallink': 'https://www.asiatoday.co.kr/kn/view.php?key=20260430010009869',
#   'link': 'https://www.asiatoday.co.kr/kn/view.php?key=20260430010009869',
#   'description': '항체뿐 아니라 세포·유전자치료제(CGT), 펩타이드, <b>인공지능</b>(AI) 신약 등 다양한 분야를 포괄한다.입주 기간은 기본 2년에 추가 2년 연장이 가능하며, 구체적인 모집은 올해 4분기부터 진행될 예정이다.... ',
#   'pubDate': 'Thu, 30 Apr 2026 15:38:00 +0900'},
#  {'title': '제주4·3 기억, AI 콘텐츠로 확장한다… 콘텐츠진흥원·4·3평화재단 맞...',
#   'originallink': 'http://www.fnnews.com/news/202604301535316268',
#   'link': 'https://n.news.naver.com/mnews/article/014/0005515905?sid=102',
#   'description': '제주4·3의 기억과 제주 고유의 역사·문화 자산을 <b>인공지능</b>(AI) 기반 콘텐츠로 확장하는 협력 사업이 추진된다. 지역의 아픈 역사와 문화적 정체성을 미래형 영상 콘텐츠로 재해석해 국내외로 알리고 청년 창작자와... ',
#   'pubDate': 'Thu, 30 Apr 2026 15:38:00 +0900'},
#  {'title': "KB금융, 초고령화사회 대응 위해 시니어 케어 확장... '피지컬 AI 돌봄 서...",
#   'originallink': 'http://www.thefirstmedia.net/news/articleView.html?idxno=198932',
#   'link': 'http://www.thefirstmedia.net/news/articleView.html?idxno=198932',
#   'description': "30일 KB금융은 오는 5월 6일부터 8일까지 서울 코엑스에서 열리는 AI EXPO KOREA 2026(국제<b>인공지능</b>대전, 이하 AI엑스포)에서 국내 금융권 최초로 휴머노이드 로봇을 활용한 시니어 케어 특화 '피지컬 AI (Physical AI) 돌봄... ",
#   'pubDate': 'Thu, 30 Apr 2026 15:38:00 +0900'},
#  {'title': '오세훈 2호 공약은 ‘마음 건강’…“누구도 외롭게 두지 않을 것”',
#   'originallink': 'https://biz.chosun.com/policy/politics/election/2026/04/30/KULOU3YK6ZHLBCSX464QVIUE7Y/?utm_source=naver&utm_medium=original&utm_campaign=biz',
#   'link': 'https://n.news.naver.com/mnews/article/366/0001161160?sid=162',
#   'description': '실직이나 이혼 등 행정 데이터를 활용해 위기 가구를 선제적으로 발굴하고, AI(<b>인공지능</b>)와 카카오톡을 결합한 ‘상시 안부 확인 시스템’을 구축한다. 영국의 ‘맨즈 쉐드(Men’s Shed)’를 벤치마킹해 목공 등 생산적... ',
#   'pubDate': 'Thu, 30 Apr 2026 15:38:00 +0900'},
#  {'title': '행안부 AI 안전신문고 1단계 개발 완료',
#   'originallink': 'http://www.ttlnews.com/news/articleView.html?idxno=3103961',
#   'link': 'http://www.ttlnews.com/news/articleView.html?idxno=3103961',
#   'description': '우리 국민이 일상에서 마주하는 위험 요소를 사진 한 장으로 포착하고, 이를 <b>인공지능</b>(AI)이 스스로 분석해 소관 부서로 즉시 넘기는 지능형 안전 행정 시대가 열린다. LG AI연구원과 한국전자기술연구원(KETI)이... ',
#   'pubDate': 'Thu, 30 Apr 2026 15:38:00 +0900'},
#  {'title': '메모리 정확도 100배·처리속도 7.6배 개선할 최적 구조 찾았다',
#   'originallink': 'https://zdnet.co.kr/view/?no=20260430151933',
#   'link': 'https://n.news.naver.com/mnews/article/092/0002420983?sid=105',
#   'description': '<b>인공지능</b>(AI) 성능을 좌우하는 메모리 반도체 정확도를 100배, 처리 속도는 7.6배 정도를 개선할 수 있는 기술이 개발됐다. 고려대학교는 유현용 전기전자공학부 교수와 DGIST 권혁준 교수 연구팀이 p-채널 실리콘과... ',
#   'pubDate': 'Thu, 30 Apr 2026 15:38:00 +0900'},
#  {'title': '해양환경공단, AI·데이터 활용 창업생태계 활성화 박차',
#   'originallink': 'https://www.s-journal.co.kr/news/articleView.html?idxno=41004',
#   'link': 'https://www.s-journal.co.kr/news/articleView.html?idxno=41004',
#   'description': '해양환경공단이 제주에서 <b>인공지능</b>(AI)·데이터 활용 확산과 창업생태계 활성화를 위한 공동 워크숍을 개최했다. 해양환경공단은 지난 22일부터 24일까지 3일간 제주 서귀포시 한국지능정보사회진흥원(이하 NIA)... ',
#   'pubDate': 'Thu, 30 Apr 2026 15:38:00 +0900'},
#  {'title': '삼성전자, 1분기 영업익 57.2조-반도체로만 53.7조 벌었다',
#   'originallink': 'http://www.techholic.co.kr/news/articleView.html?idxno=221017',
#   'link': 'http://www.techholic.co.kr/news/articleView.html?idxno=221017',
#   'description': '특히 영업이익은 국내 기업 가운데 역대 최고를 넘어 글로벌 기업 가운데서도 최고의 수준을 기록, <b>인공지능</b>(AI) 확산에 따른 메모리 수요 증가세로인한 반도체 슈퍼사이클의 최대 수혜자임을 증명했다. 삼성전자는... ',
#   'pubDate': 'Thu, 30 Apr 2026 15:38:00 +0900'},
#  {'title': '광주광역시, 자동차·<b>인공지능</b>·에너지 유망 기업 11개사와 1605억원 투자...',
#   'originallink': 'http://www.fnnews.com/news/202604301519258427',
#   'link': 'https://n.news.naver.com/mnews/article/014/0005515902?sid=102',
#   'description': '광주광역시가 30일 자동차·<b>인공지능</b>(AI)·에너지 분야 유망 기업 11개사와 총 1605억원 규모의 투자 유치 협약을 체결했다. 11개 기업은 ㈜디엔, ㈜나전, ㈜리얼디자인테크, 하이퍼협동조합, ㈜달구, ㈜모리스, ㈜에스더블유엠... ',
#   'pubDate': 'Thu, 30 Apr 2026 15:37:00 +0900'}]
